# %% [markdown]
# # Results of anova and pairwise Tukey HSD

# %%
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
# Out:
#         1-way ANOVA
# F-value     2518.62
# p-value    < 0.0001
